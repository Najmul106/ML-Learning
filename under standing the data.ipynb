# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'train.csv'
df = pd.read_csv(file_path)

df.shape
# Out:
# (1000, 18)

# %%
df.sample(5)
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 854     855  CA-2017-123274  19/02/2017  24/02/2017  Standard Class
# 852     853  CA-2017-113747  28/05/2017  04/06/2017  Standard Class
# 104     105  US-2016-156867  13/11/2016  17/11/2016  Standard Class
# 5         6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 759     760  CA-2018-133333  18/09/2018  22/09/2018  Standard Class
#
#     Customer ID      Customer Name    Segment        Country           City  \
# 854    GT-14710          Greg Tran   Consumer  United States  New York City
# 852    VD-21670  Valerie Dominguez   Consumer  United States        Jackson
# 104    LC-16870      Lena Cacioppo   Consumer  United States         Aurora
# 5      BH-11710    Brosina Hoffman   Consumer  United States    Los Angeles
# 759    BF-11020  Barry Französisch  Corporate  United States      Green Bay
#
#            State  Postal Code   Region       Product ID         Category  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0         1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1         2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2         3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3         4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4         5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ..      ...             ...         ...         ...             ...
# 995     996  CA-2015-117639  21/05/2015  25/05/2015  Standard Class
# 996     997  CA-2016-162537  28/10/2016  03/11/2016  Standard Class
# 997     998  CA-2016-162537  28/10/2016  03/11/2016  Standard Class
# 998     999  CA-2016-162537  28/10/2016  03/11/2016  Standard Class
# 999    1000  CA-2016-162537  28/10/2016  03/11/2016  Standard Class
#
#     Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID   Postal Code        Sales
# count  1000.000000   1000.000000  1000.000000
# mean    500.500000  53500.842000   241.130768
# std     288.819436  31494.145045   595.878568
# min       1.000000   1841.000000     1.080000
# 25%     250.750000  19639.500000    18.378000
# 50%     500.500000  50315.000000    55.740000
# 75%     750.250000  85023.000000   213.206250
# max    1000.000000  98661.000000  8159.952000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(df["State"])
# Out:
# <Axes: xlabel='count', ylabel='State'>

# %%
sns.countplot(df["Category"])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
sns.countplot(df["Segment"])
# Out:
# <Axes: xlabel='count', ylabel='Segment'>

# %%
sns.countplot(df["Ship Mode"])
# Out:
# <Axes: xlabel='count', ylabel='Ship Mode'>

# %%
sns.scatterplot(x='Sales', y='Sub-Category', data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Sub-Category'>

# %%
# Query using a string expression
result = df.query('Sales > 4000 and Sales<9000')
result
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 165     166  CA-2015-139892  08/09/2015  12/09/2015  Standard Class
# 353     354  CA-2017-129714  01/09/2017  03/09/2017     First Class
# 509     510  CA-2016-145352  16/03/2016  22/03/2016  Standard Class
# 683     684  US-2018-168116  04/11/2018  04/11/2018        Same Day
#
#     Customer ID         Customer Name      Segment        Country  \
# 165    BM-11140          Becky Martin     Consumer  United States
# 353    AB-10060       Adam Bellavance  Home Office  United States
# 509    CM-12385  Christopher Martinez     Consumer  United States
# 683    GT-14635        Grant Thornton    Corporate  United States
#
#               City           State  Postal Code   Region       Product ID  \
# 165    San Antonio           Texas        78207  Central  TEC-MA-10000822
# 353  New York City        New York        10009     East  OFF-BI-10004995
# ...

# %%
sns.boxplot(x='Order Date',y='Sales',data=df,hue='Sub-Category')
# Out:
# <Axes: xlabel='Order Date', ylabel='Sales'>
# C:\Users\NAJMUL HASAN\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\NAJMUL HASAN\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(x='Sales', y='Sub-Category',hue="Category", data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Sub-Category'>

# %%
sns.boxplot(x='Sales', y='Category',hue="Sub-Category", data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Category'>
