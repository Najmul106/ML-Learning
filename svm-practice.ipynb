# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.svm import SVC

# %%
df=pd.read_csv("/kaggle/input/datasets/utkarshx27/breast-cancer-dataset-used-royston-and-altman/gbsg.csv")

# %%
df.shape
# Out:
# (686, 12)

# %%
df.head()
# Out:
#    Unnamed: 0   pid  age  meno  size  grade  nodes  pgr  er  hormon  rfstime  \
# 0           1   132   49     0    18      2      2    0   0       0     1838
# 1           2  1575   55     1    20      3     16    0   0       0      403
# 2           3  1140   56     1    40      3      3    0   0       0     1603
# 3           4   769   45     0    25      3      1    0   4       0      177
# 4           5   130   65     1    30      2      5    0  36       1     1855
#
#    status
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0

# %%
df.tail()
# Out:
#      Unnamed: 0   pid  age  meno  size  grade  nodes   pgr    er  hormon  \
# 681         682   586   51     0    30      3      2  1152    38       1
# 682         683  1273   64     1    26      2      2  1356  1144       1
# 683         684  1525   57     1    35      3      1  1490   209       1
# 684         685   736   44     0    21      2      3  1600    70       0
# 685         686   894   80     1     7      2      7  2380   972       1
#
#      rfstime  status
# 681     1760       0
# 682     1152       0
# 683     1342       0
# 684      629       0
# 685      758       0

# %%
df.sample(5)
# Out:
#      Unnamed: 0   pid  age  meno  size  grade  nodes  pgr   er  hormon  \
# 520         521  1305   60     0    23      2      3  136  507       0
# 25           26  1181   49     1    14      2      1    0    0       0
# 169         170   984   59     1    30      2     13    7   81       1
# 78           79   133   52     1    25      2     13    0    0       1
# 369         370   856   57     1    15      2      3   44   78       1
#
#      rfstime  status
# 520     1642       0
# 25      2051       0
# 169      410       1
# 78      1826       0
# 369     1481       1

# %%
X=df.iloc[:,2:4]

# %%
X
# Out:
#      age  meno
# 0     49     0
# 1     55     1
# 2     56     1
# 3     45     0
# 4     65     1
# ..   ...   ...
# 681   51     0
# 682   64     1
# 683   57     1
# 684   44     0
# 685   80     1
#
# [686 rows x 2 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 681    0
# 682    0
# 683    0
# 684    0
# 685    0
# Name: status, Length: 686, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=.2)

# %%
DecisionBoundaryDisplay.from_estimator(
    svm,
    X,
    response_method="predict",
    alpha=0.8,
    cmap="Pastel1",
    xlabel=X_train.columns[0],  # Fix: Use .columns instead of .feature_names
    ylabel=X_train.columns[1]   # Fix: Use .columns instead of .feature_names
)

# Fix: Use .iloc for Pandas slicing
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], 
            c=y, 
            s=20, edgecolors="k")
plt.show()
