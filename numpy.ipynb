# %%
import numpy as np

# %%
arr=np.array([10,20,30,40])
arr
# Out:
# array([10, 20, 30, 40])

# %%
arr1=np.array([[10,20,30,40],[50,60,70,80]])

# %%
arr[0:3]
# Out:
# array([10, 20, 30])

# %%
arr1[0:2,0:3]
# Out:
# array([[10, 20, 30],
#        [50, 60, 70]])

# %%
arr1[1,2:]
# Out:
# array([70, 80])

# %%
np.size(arr1)
# Out:
# 8

# %%
np.shape(arr1)
# Out:
# (2, 4)

# %%
np.ndim(arr)
# Out:
# 1

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
a=np.array([10,20,30])

# %%
a.shape
# Out:
# (3,)

# %%
a.size
# Out:
# 3

# %%
len(a)
# Out:
# 3

# %%
a.ndim
# Out:
# 1

# %%
a.dtype
# Out:
# dtype('int32')

# %%
a.astype(float)
# Out:
# array([10., 20., 30.])

# %%
a
# Out:
# array([10, 20, 30])

# %%
b=np.array([40,50,60])

# %%
b
# Out:
# array([40, 50, 60])

# %%
np.subtract(a,b)
# Out:
# array([-30, -30, -30])

# %%
np.add(a,b)
# Out:
# array([50, 70, 90])

# %%
np.multiply(a,b)
# Out:
# array([ 400, 1000, 1800])

# %%
np.divide(a,b)
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
np.exp(b)
# Out:
# array([2.35385267e+17, 5.18470553e+21, 1.14200739e+26])

# %%
np.sqrt(b)
# Out:
# array([6.32455532, 7.07106781, 7.74596669])

# %%
a=np.array([5,3])
b=np.array([2,3])
np.power(a,b)
# Out:
# array([25, 27])

# %%
ar1=np.array([[10, 20],[30,90]])

# %%
ar2=np.array([[40, 50],[70, 60]])

# %%
np.concatenate([ar1,ar2])
# Out:
# array([[10, 20],
#        [30, 90],
#        [40, 50],
#        [70, 60]])

# %%
np.concatenate([ar1,ar2],axis=1)
# Out:
# array([[10, 20, 40, 50],
#        [30, 90, 70, 60]])

# %%
np.hstack([ar1,ar2])
# Out:
# array([[10, 20, 40, 50],
#        [30, 90, 70, 60]])

# %%
np.vstack([ar1,ar2])
# Out:
# array([[10, 20],
#        [30, 90],
#        [40, 50],
#        [70, 60]])

# %%
ar3=np.array([20,40,60,80])

# %%
np.array_split(ar3,3)
# Out:
# [array([20, 40]), array([60]), array([80])]

# %%
h=np.array([4,5,6,7,15])
g=np.array([8,9,10,11])
np.append(h,g)
# Out:
# array([ 4,  5,  6,  7, 15,  8,  9, 10, 11])

# %%
np.insert(ar3,1,6)
# Out:
# array([20,  6, 40, 60, 80])

# %%
np.delete(ar3,1)
# Out:
# array([20, 60, 80])

# %%
c=np.array([[20,40],[50,60]])

# %%
np.append(c,90)
# Out:
# array([20, 40, 50, 60, 90])

# %%
d=np.insert(c,1,50)

# %%
np.delete(d,1)
# Out:
# array([20, 40, 50, 60])

# %%
np.delete(c,1,axis=1)
# Out:
# array([[20],
#        [50]])

# %%
T=np.array([1,2,8,3,4,5,6])

# %%
np.sort(T)
# Out:
# array([1, 2, 3, 4, 5, 6, 8])

# %%
S=np.where(T%2==0)

# %%
S#-->it produce index number
# Out:
# (array([1, 2, 4, 6], dtype=int64),)

# %%
Tania=np.array([20,40,60,70])

# %%
np.sum(Tania)
# Out:
# 190

# %%
np.min(Tania)
# Out:
# 20

# %%
np.max(Tania)
# Out:
# 70

# %%
np.size(Tania)
# Out:
# 4

# %%
np.mean(Tania)
# Out:
# 47.5

# %%
np.cumsum(Tania)
# Out:
# array([ 20,  60, 120, 190])

# %%
np.cumprod(Tania)
# Out:
# array([     20,     800,   48000, 3360000])

# %%
L=[100,150,199,200,250,130]
O=[10,50,30,40,30,10]

# %%
price=np.array(L)

# %%
Quantity=np.array(O)

# %%
price,Quantity
# Out:
# (array([100, 150, 199, 200, 250, 130]), array([10, 50, 30, 40, 30, 10]))

# %%
v=np.cumprod([price,Quantity],axis=0)

# %%
v
# Out:
# array([[ 100,  150,  199,  200,  250,  130],
#        [1000, 7500, 5970, 8000, 7500, 1300]])

# %%
v[1].sum()
# Out:
# 31270
